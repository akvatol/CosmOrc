# %%
import os
import re
import pandas as pd

parameter_list = ['Zero-point correction', 'Thermal correction to Energy', 'Thermal correction to Enthalpy', 'Thermal correction to Gibbs Free Energy', 'Sum of electronic and zero-point Energies',
     'Sum of electronic and thermal Energies', 'Sum of electronic and thermal Enthalpies', 'Sum of electronic and thermal Free Energies']

properties_list = ['Total', 'Electronic', 'Translational', 'Rotational', 'Vibrational']

Freaks_global = []
Freaks_current = []
Total_E, Electronic_E, Translational_E, Rotational_E, Vibrational_E = [],[],[],[],[]
Total_S, Electronic_S, Translational_S, Rotational_S, Vibrational_S = [],[],[],[],[]
D_freaks_rev_sm = {}

file_vec = []
file_vec_new = []
for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if file.endswith(".log"):
            current_way = os.path.join(root, file)
            file_vec.append(current_way)
print (file_vec, sep = '\n')


D_main = {properties:[] for properties in parameter_list}
    
for file in file_vec:
    file_name = str(file)
    with open(file_name, "r") as f:
        #print (f.readlines().index(' - Thermochemistry -\n'))
        lines_vector = f.readlines()
        if " - Thermochemistry -\n" in lines_vector:
            file_vec_new.append(file_name)
            for line in lines_vector:
                Armageddez = re.search ('(\w+)\s\-\-\s*([-\d.]+)\s*([-\d.]+)\s*([-\d.]+)', line)
                if Armageddez:
                    if (Armageddez.group(1)) == 'Frequencies':
                        #print (Armageddez.group(2), Armageddez.group(3), Armageddez.group(4))
                        for i in range (2,5):
                            Freaks_current.append(Armageddez.group(i))
                        
                for i in parameter_list:
                    Nechto = re.search ('(-?[0-9]{1,4}\.[0-9]{6})', line)
                    if Nechto:
                        if i in line:
                            D_main[i].append(Nechto.group(1))
                            #print (D_main)
                for k in properties_list:
                    Nerd = re.search('([0-9]{1,4}\.[0-9]{3})\s{2,15}([0-9]{1,4}\.[0-9]{3})\s{2,15}([0-9]{1,4}\.[0-9]{3})', line)
                    if Nerd:
                        if k in line:
                            current_E_Thermal = k + '_E'
                            current_S = k + '_S'
                            globals()[current_E_Thermal].append(line.split()[1])
                            globals()[current_S].append(line.split()[3])
    Freaks_global.append(Freaks_current)
    Freaks_current = []
#print(Freaks_global)
print (file_vec_new)
# Out:
# ['/home/greyfox21/Documents/Gaussian/IPA.log', '/home/greyfox21/Documents/Gaussian/acetophennel.log', '/home/greyfox21/Documents/Gaussian/Freq_MnPNH2_st5released.log', '/home/greyfox21/Documents/Gaussian/Freq_MnPNH2_st4released.log', '/home/greyfox21/Documents/Gaussian/acetophenol.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_s_aco_atmosphereCO_scanCO.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_s_acoh_svyazCO.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_aco_protonirovanie_drugoe.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_sc2_aco_tyanuliO_k_Ru.log']
# ['/home/greyfox21/Documents/Gaussian/IPA.log', '/home/greyfox21/Documents/Gaussian/acetophennel.log', '/home/greyfox21/Documents/Gaussian/Freq_MnPNH2_st5released.log', '/home/greyfox21/Documents/Gaussian/Freq_MnPNH2_st4released.log', '/home/greyfox21/Documents/Gaussian/acetophenol.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_s_acoh_svyazCO.log', '/home/greyfox21/Documents/Gaussian/gaussian/oh_aco_protonirovanie_drugoe.log']

# %%
D_properties = {'Total_E':Total_E, 'Electronic_E':Electronic_E, 'Translational_E':Translational_E, 'Rotational_E': Rotational_E, 'Vibrational_E':Vibrational_E,
               'Total_S':Total_S, 'Electronic_S':Electronic_S, 'Translational_S':Translational_S, 'Rotational_S': Rotational_S, 'Vibrational_S':Vibrational_S}
table_Gaus_properties = pd.DataFrame(D_properties)
table_Gaus_properties.index = file_vec_new
print (table_Gaus_properties)
# Out:
#                                                    Electronic_E Electronic_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                0.000        0.000
# /home/greyfox21/Documents/Gaussian/acetophennel...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/acetophenol.log        0.000        0.000
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.000        0.000
#
#                                                    Rotational_E Rotational_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                0.889       24.379
# /home/greyfox21/Documents/Gaussian/acetophennel...        0.889       28.735
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.889       35.785
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.889       36.562
# /home/greyfox21/Documents/Gaussian/acetophenol.log        0.889       28.840
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.889       35.741
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.889       36.095
#
#                                                     Total_E  Total_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log           71.166   67.035
# /home/greyfox21/Documents/Gaussian/acetophennel...   92.389   87.088
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...  268.280  197.106
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...  302.303  207.494
# /home/greyfox21/Documents/Gaussian/acetophenol.log  105.758   81.893
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...  175.491  169.524
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...  176.209  181.092
#
#                                                    Translational_E  \
# /home/greyfox21/Documents/Gaussian/IPA.log                   0.889
# /home/greyfox21/Documents/Gaussian/acetophennel...           0.889
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...           0.889
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...           0.889
# /home/greyfox21/Documents/Gaussian/acetophenol.log           0.889
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...           0.889
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...           0.889
#
#                                                    Translational_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                  38.198
# /home/greyfox21/Documents/Gaussian/acetophennel...          40.263
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...          44.046
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...          44.450
# /home/greyfox21/Documents/Gaussian/acetophenol.log          40.313
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...          44.343
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...          44.343
#
#                                                    Vibrational_E Vibrational_S
# /home/greyfox21/Documents/Gaussian/IPA.log                69.388         4.458
# /home/greyfox21/Documents/Gaussian/acetophennel...        90.612        18.090
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...       266.502       117.275
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...       300.525       126.483
# /home/greyfox21/Documents/Gaussian/acetophenol.log       103.981        12.740
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...       173.713        89.439
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...       174.431       100.653

# %%
table_Gaus_main = pd.DataFrame(D_main)
table_Gaus_main.index = file_vec_new

# %%
D_freaks_rev_sm = dict(zip(file_vec,Freaks_global))
print (D_freaks_rev_sm)
# Out:
', '934.7617', '982.1504', '999.5396', '1009.5282', '1014.7058', '1036.0088', '1041.5618', '1048.8450', '1063.5282', '1103.3596', '1170.4683', '1183.2368', '1189.8181', '1214.1506', '1246.8040', '1253.9365', '1296.2786', '1339.6827', '1374.8388', '1404.0053', '1423.4248', '1425.0038', '1434.7952', '1446.2585', '1478.7782', '1499.6848', '1524.9600', '1562.8730', '1567.1377', '1627.3898', '1644.8219', '1663.9085', '1693.9287', '2132.3661', '2137.4758', '2219.3240', '2279.5150', '2938.5310', '3042.3911', '3114.6510', '3181.5710', '3186.4004', '3191.0222', '3196.3663', '3204.4012', '3211.6915', '3212.4155', '3233.1971', '3731.1155'], '/home/greyfox21/Documents/Gaussian/Freq_MnPNH2_st5released.log': ['18.9078', '20.9257', '25.8405', '31.6215', '36.3882', '48.1163', '56.9882', '62.3771', '68.1362', '74.0610', '84.2939', '87.9939', '93.8723', '100.2890', '111.3841', '114.0421', '117.8773', '129.3325', '183.3589', '193.5221', '217.8628', '230.5173', '245.1446', '259.4183', '272.1740', '274.8032', '287.3730', '342.70 ...

# %%
table_Gaus_global = pd.concat([table_Gaus_main, table_Gaus_properties], axis = 1)
table_Gaus_global.to_csv('Gaussian_Vica.csv', sep='\t')
print (table_Gaus_global)
# Out:
#                                                    Sum of electronic and thermal Energies  \
# /home/greyfox21/Documents/Gaussian/IPA.log                                    -194.000401
# /home/greyfox21/Documents/Gaussian/acetophennel...                            -384.296226
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                           -2621.834276
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                           -2813.290663
# /home/greyfox21/Documents/Gaussian/acetophenol.log                            -385.456518
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                           -2082.200441
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                           -2082.293647
#
#                                                    Sum of electronic and thermal Enthalpies  \
# /home/greyfox21/Documents/Gaussian/IPA.log                                      -193.999457
# /home/greyfox21/Documents/Gaussian/acetophennel...                              -384.295282
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                             -2621.833332
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                             -2813.289719
# /home/greyfox21/Documents/Gaussian/acetophenol.log                              -385.455574
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                             -2082.199496
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                             -2082.292703
#
#                                                    Sum of electronic and thermal Free Energies  \
# /home/greyfox21/Documents/Gaussian/IPA.log                                         -194.031307
# /home/greyfox21/Documents/Gaussian/acetophennel...                                 -384.336661
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                                -2621.926983
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                                -2813.388306
# /home/greyfox21/Documents/Gaussian/acetophenol.log                                 -385.494484
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                                -2082.280043
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                                -2082.378746
#
#                                                    Sum of electronic and zero-point Energies  \
# /home/greyfox21/Documents/Gaussian/IPA.log                                       -194.004694
# /home/greyfox21/Documents/Gaussian/acetophennel...                               -384.304005
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                              -2621.863264
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                              -2813.322066
# /home/greyfox21/Documents/Gaussian/acetophenol.log                               -385.463191
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                              -2082.224578
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                              -2082.319770
#
#                                                    Thermal correction to Energy  \
# /home/greyfox21/Documents/Gaussian/IPA.log                             0.113410
# /home/greyfox21/Documents/Gaussian/acetophennel...                     0.147232
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                     0.427531
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                     0.481750
# /home/greyfox21/Documents/Gaussian/acetophenol.log                     0.168536
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                     0.279662
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                     0.280806
#
#                                                    Thermal correction to Enthalpy  \
# /home/greyfox21/Documents/Gaussian/IPA.log                               0.114354
# /home/greyfox21/Documents/Gaussian/acetophennel...                       0.148176
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                       0.428475
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                       0.482694
# /home/greyfox21/Documents/Gaussian/acetophenol.log                       0.169480
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                       0.280606
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                       0.281750
#
#                                                    Thermal correction to Gibbs Free Energy  \
# /home/greyfox21/Documents/Gaussian/IPA.log                                        0.082504
# /home/greyfox21/Documents/Gaussian/acetophennel...                                0.106798
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                                0.334824
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...                                0.384107
# /home/greyfox21/Documents/Gaussian/acetophenol.log                                0.130571
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                                0.200060
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...                                0.195708
#
#                                                    Zero-point correction  \
# /home/greyfox21/Documents/Gaussian/IPA.log                      0.109116
# /home/greyfox21/Documents/Gaussian/acetophennel...              0.139453
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...              0.398543
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...              0.450347
# /home/greyfox21/Documents/Gaussian/acetophenol.log              0.161863
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...              0.255524
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...              0.254684
#
#                                                    Electronic_E Electronic_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                0.000        0.000
# /home/greyfox21/Documents/Gaussian/acetophennel...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/acetophenol.log        0.000        0.000
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.000        0.000
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.000        0.000
#
#                                                    Rotational_E Rotational_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                0.889       24.379
# /home/greyfox21/Documents/Gaussian/acetophennel...        0.889       28.735
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.889       35.785
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...        0.889       36.562
# /home/greyfox21/Documents/Gaussian/acetophenol.log        0.889       28.840
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.889       35.741
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...        0.889       36.095
#
#                                                     Total_E  Total_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log           71.166   67.035
# /home/greyfox21/Documents/Gaussian/acetophennel...   92.389   87.088
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...  268.280  197.106
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...  302.303  207.494
# /home/greyfox21/Documents/Gaussian/acetophenol.log  105.758   81.893
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...  175.491  169.524
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...  176.209  181.092
#
#                                                    Translational_E  \
# /home/greyfox21/Documents/Gaussian/IPA.log                   0.889
# /home/greyfox21/Documents/Gaussian/acetophennel...           0.889
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...           0.889
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...           0.889
# /home/greyfox21/Documents/Gaussian/acetophenol.log           0.889
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...           0.889
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...           0.889
#
#                                                    Translational_S  \
# /home/greyfox21/Documents/Gaussian/IPA.log                  38.198
# /home/greyfox21/Documents/Gaussian/acetophennel...          40.263
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...          44.046
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...          44.450
# /home/greyfox21/Documents/Gaussian/acetophenol.log          40.313
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...          44.343
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...          44.343
#
#                                                    Vibrational_E Vibrational_S
# /home/greyfox21/Documents/Gaussian/IPA.log                69.388         4.458
# /home/greyfox21/Documents/Gaussian/acetophennel...        90.612        18.090
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...       266.502       117.275
# /home/greyfox21/Documents/Gaussian/Freq_MnPNH2_...       300.525       126.483
# /home/greyfox21/Documents/Gaussian/acetophenol.log       103.981        12.740
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...       173.713        89.439
# /home/greyfox21/Documents/Gaussian/gaussian/oh_...       174.431       100.653
